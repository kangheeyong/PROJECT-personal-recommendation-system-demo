# %%
#-*- coding: utf-8 -*-
import requests
import bs4

# %%
NAVER_SHOPPING_URL = "http://shopping.naver.com/search/all_search.nhn"
data = requests.get(NAVER_SHOPPING_URL,
                    params={
                        'query': '화장품'
                        # 여기에 추후에 가격정보나 다른 파라미터 추가
                    })
 
bs_data = bs4.BeautifulSoup(data.text)

# %%
bs_data
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="always" name="referrer"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible">
# <meta content="No-Cache" http-equiv="Pragma"/>
# <meta content="now" http-equiv="Expires"/>
# <meta content="화장품 : 네이버쇼핑" property="og:title"/>
# <meta content="'화장품'의 네이버쇼핑 검색 결과 입니다." property="og:description"/>
# <meta content="https://ssl.pstatic.net/imgshopping/static/mo2014/icon/og_shopping_v2.png" property="og:image"/>
# <title>화장품 : 네이버쇼핑</title>
# <link href="https://ssl.pstatic.net/imgshopping/static/favicon_v4.ico" rel="shortcut icon" type="image/x-icon"/>
# <link charset="utf-8" href="https://ssl.pstatic.net/imgshopping/static/pc-real-2019/css/_global_v1.css?202003031700" rel="stylesheet" type="text/css"/>
# <link charset="utf-8" href="https://ssl.pstatic.net/imgshopping/static/pc-real-2019/css/_search_v1.css?202003031700" rel="stylesheet" type="text/css"/>
# </meta></head>
# <body class="">
# <div id="u_skip">
# <a href="#lnb" onclick="document.getElementById('lnb').tabIndex=-1;document.getElementById('lnb').focus();return false;"><span>메인 메뉴로 바로가기</span></a>
# <a href="#snb" onclick="document.getElementById('snb').tabIndex=-1;document.getElementById('snb').focus();return false;"><span>하위 메뉴로 바로가기</span></a>
# <a href="#content" onclick="document.getElementById('content').tabIndex=-1;document.getElementById('content').focus();return false;"><span>본문으로 바로가기</span></a>
# </div>
# <div class="" id="wrap">
# <div class="g_header" id="header"><iframe class="bug_fix" frameborder="0" src="about:blank" title="버그픽스용" width="100%"></iframe>
# <div class="co_header_fix">
# <div class="co_header co_header_gnb">
# <div class="co_header_inner">
# <div class="co_site">
# <a class="co_naver" href="https://www.naver.com/" title="나의 경쟁력, 네이버">NAVER</a><!--N=a:GNB.naver-->
# <a class="co_npay" href="https://order.pay.naver.com/home?frm=s_logo" title="네이버 아이디로 간편구매, 네이버페이">네이버페이</a><!--N=a:GNB.naverpay-->
# </div>
# <div class="shopping_gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# </div>
# <span class="g_mask_white"></span>
# <span class="g_mask_black"></span>
# </div>
# <div class="co_header co_header_shop">
# <div class="co_header_inner">
# <h1 class="co_tit"><a _clickcode="home" _lite="GNL" _normal="SNB" href="https://shopping.naver.com" title="">NAVER 쇼핑</a><!--N=a:SNB.home--></h1>
# <div class="co_srh">
# <h2 class="blind">검색영역</h2>
# <fieldset>
# <form action="/search/all.nhn" class="_search_form" method="get" name="search" onsubmit="return false;">
# <legend>네이버쇼핑 검색</legend>
# <div class="co_srh_area" id="autocompleteWrapper">
# <input accesskey="s" autocomplete="off" class="co_srh_input _input" maxlength="255" name="query" title="검색어 입력" type="text" value="화장품"/>
# <input name="cat_id" type="hidden"/>
# <input id="frm" name="frm" type="hidden" value="NVSHSRC"/>
# <!-- 접기/펼치기 버튼 : [AU] _toggle, _toggleIcon -->
# <a class="co_srh_auto _toggle" href="#"><span class="co_more _toggleIcon">자동완성 펼치기</span></a>
# <div class="co_ly_tooltip">
# <iframe class="bug_fix" frameborder="0" src="about:blank" title="버그픽스용" width="100%"></iframe>
# <!-- 접기/펼치기 버튼 툴팁 : [AU] _toggleTooltip -->
# <span class="co_tooltip_inner _toggleTooltip">자동완성 펼치기</span>
# </div>
# <!-- 검색버튼 : [AU] _search -->
# <a _lite="GNL" _normal="SNB" class="co_srh_btn _search" href="#">네이버쇼핑 검색</a>
# <!--code@-->
# <!--@code lang="html" title="HTML 자동완성 레이어" hl="auto"-->
# <!-- 자동완성 레이어 : [AU] _suggestView -->
# <div class="co_ly_auto _suggestView">
# <iframe class="bug_fix" frameborder="0" src="about:blank" title="버그픽스용" width="100%"></iframe>
# <div class="co_auto_fix">
# <!-- [AU] _noticeArea -->
# <div class="co_basis _noticeArea">
# <p class="co_basis_txt">현재 자동완성 기능을 사용하고 계십니다.</p>
# </div>
# <!-- [AU] _resultArea -->
# <div class="co_basis _resultArea" style="display: none">
# <!-- [AU] _resultBox -->
# <ul class="_resultBox"></ul>
# <ul class="_resultBox"></ul>
# <ul class="_resultBox"></ul>
# <ul class="_resultBox"></ul>
# </div>
# <div class="co_help">
# <a href="https://help.naver.com/support/contents/contents.nhn?serviceNo=606&amp;categoryNo=1994" target="_blank">도움말</a><!--N=a:sch.achelp-->
# <span class="co_bar">|</span>
# <!-- [AU] _off -->
# <a class="_off" href="#">기능끄기</a><!--N=a:sch.acoff-->
# <div class="co_ly_help">기능을 다시 켤 때는 <span class="co_ico_srh">검색창</span>을 클릭하세요</div>
# </div>
# <!-- [AU] _preview -->
# <div class="co_expand _previewArea">
# </div>
# <!-- Theme -->
# <div class="co_expand _themeArea">
# <div class="co_expand_inner _themeInnerArea">
# <a class="co_goods N=a:sch.eventimage" href="#">
# <img alt="" height="100" src="https://ssl.pstatic.net/imgshopping/static/m3/im/placeholder.png" width="100"/>
# <strong class="co_theme_name"></strong>
# <div class="co_date"></div>
# <span class="co_compare">기획전 바로가기</span>
# </a>
# <!--N=a:sch.eventimage-->
# </div>
# </div>
# </div>
# </div>
# <!--code@--></div>
# </form>
# <a _clickcode="detailsearch" _lite="GNL" _normal="SNB" class="co_srh_detail" href="#" id="_detailSearchButton">
# <span class="co_detail_txt">상세검색</span>
# <span class="co_detail_more">펼치기</span></a>
# <div class="co_ly_detail" id="_detailSearchDiv"><!-- [D] 활성화 시 class="on" 추가 -->
# <iframe class="bug_fix" frameborder="0" src="about:blank" title="버그픽스용" width="100%"></iframe>
# <div class="co_detail_fix">
# <strong class="co_detail_tit">상세검색</strong>
# <div class="co_detail">
# <p class="co_preview _preview"></p><table border="1" class="co_tbl_detail" role="presentation">
# <colgroup>
# <col style="width:171px"/>
# <col/>
# </colgroup>
# <tbody>
# <tr class="co_top">
# <th scope="row"><label class="stit" for="lb_srh_basis"><strong>기본검색</strong></label></th>
# <td><input class="co_srh_input _base" id="lb_srh_basis" maxlength="50" name="" type="text"/></td>
# </tr>
# <tr class="co_top">
# <th scope="row"><strong>상세검색</strong></th>
# <td><p class="co_dsc"><strong class="co_bright">*</strong>기본 검색의 결과 범위를 줄이고자 할 때 사용합니다.<br/>여러개의 단어를 입력할 때는<span class="co_bright">쉼표 (,)</span>로 구분해서 입력하세요.</p></td>
# </tr>
# <tr>
# <th class="co_result" scope="row"><label for="lb_srh_include">결과내 재검색 단어 (+)</label></th>
# <td><input class="co_srh_input _include" id="lb_srh_include" maxlength="50" name="" type="text"/></td>
# </tr>
# <tr>
# <th scope="row"><label for="lb_srh_exact">정확히 일치하는 문장 (“”)</label></th>
# <td><input class="co_srh_input _exact" id="lb_srh_exact" maxlength="50" name="" type="text"/></td>
# </tr>
# <tr>
# <th scope="row"><label for="lb_srh_exclude">제외하는 단어 (-)</label></th>
# <td>
# <input class="co_srh_input _exclude" id="lb_srh_exclude" maxlength="50" name="" type="text"/>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# <p class="co_or_none"><strong class="co_bright">*</strong> 네이버쇼핑내에선 OR 검색어는 제공하지 않습니다.</p>
# <div class="co_btn">
# <a class="co_advise" href="https://help.naver.com/support/contents/contents.nhn?serviceNo=606&amp;categoryNo=1911" target="_blank">도움말</a><!--N=a:sch*d.help-->
# <a class="co_refresh" href="#">초기화</a><!--N=a:sch*d.reset-->
# <a class="co_confirm" href="#">검색</a><!--N=a:sch*d.search-->
# <a class="co_cancel" href="#">닫기</a><!--N=a:sch*d.close-->
# </div>
# <a class="co_close" href="#">상세검색 닫기</a><!--N=a:sch*d.x-->
# </div>
# </div>
# </fieldset>
# </div>
# <!-- 카테고리 -->
# <a class="co_category_btn" href="#" id="_categoryLayerButton">카테고리</a><!--N=a:SNB.category-->
# <div class="co_ly_category" id="_categoryLayerWrapper"><!-- [D] 선택시 class="on" 추가 -->
# <iframe class="bug_fix" frameborder="0" src="about:blank" title="버그픽스용" width="100%"></iframe>
# <h2 class="blind">카테고리 메뉴</h2>
# <div class="co_category_menu">
# <ul class="co_category_list">
# <li class="co_menu_wear">
# <a class="on _category1" href="javascript:;" id="_fashionCategory1"><em>패션의류</em></a><!--N=a:SNB*l.50000000--><!-- [D] 선택시 class="on" 추가 -->
# <div class="co_ly_inner on"><!-- [D] 선택시 class="on" 추가 -->
# <div class="co_position">
# <div class="co_col" style="height:409px">
# <div class="co_cel">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000167">여성의류<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000805">니트/스웨터</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000806">카디건</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000807">원피스</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000803">티셔츠</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000804">블라우스/셔츠</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000814">점퍼</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000815">재킷</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000813">코트</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000809">청바지</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000808">스커트</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000812">레깅스</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000810">바지</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000818">트레이닝복</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000817">조끼</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000816">정장세트</a></li>
# </ul>
# </div>
# </div>
# <div class="co_col" style="height:409px">
# <div class="co_cel">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000169">남성의류<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000831">니트/스웨터</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000830">티셔츠</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000833">셔츠/남방</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000832">카디건</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000837">점퍼</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000838">재킷</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000839">코트</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000835">청바지</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000836">바지</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000834">조끼</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000840">정장세트</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000841">트레이닝복</a></li>
# </ul>
# </div>
# </div>
# <div class="co_col" style="height:409px">
# <div class="co_cel">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000168">여성 언더웨어/잠옷<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000823">브라</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000824">팬티</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000825">브라팬티세트</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001452">보정속옷</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000826">잠옷/홈웨어</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000827">슬립</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000828">러닝/캐미솔</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000829">속치마/속바지</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001453">시즌성내의</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001454">언더웨어소품</a></li>
# </ul>
# </div>
# </div>
# <div class="co_col" style="height:409px">
# <div class="co_cel">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000170">남성 언더웨어/잠옷<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000845">팬티</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000846">러닝</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000847">러닝팬티세트</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000848">잠옷/홈웨어</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001455">보정속옷</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001456">시즌성내의</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="co_help">
# <a class="co_all" href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000000">패션의류 카테고리 전체보기<span class="co_more"></span></a><!--N=a:SNB*l.more-->
# <a class="co_close" href="javascript:;"><span class="blind">패션의류 카테고리 닫기</span></a><!--N=a:SNB*l.close-->
# </div>
# </div>
# </li>
# <li class="co_menu_sundries">
# <a class="_category1" href="javascript:;"><em>패션잡화</em></a><!--N=a:SNB*l.50000001-->
# <div class="co_ly_inner">
# <div class="co_position">
# <div class="co_col" style="height:442px">
# <div class="co_cel" style="height:189px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000173">여성신발<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001462">부츠</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000779">부티</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001461">워커</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001459">단화</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001460">힐/펌프스</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001463">운동화</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000781">실내화</a></li>
# </ul>
# </div>
# <div class="co_cel">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000179">지갑<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000661">머니클립</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001471">여성지갑</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001472">남성지갑</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000662">카드/명함지갑</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000664">동전지갑</a></li>
# </ul>
# </div>
# </div>
# <div class="co_col" style="height:442px">
# <div class="co_cel" style="height:189px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000174">남성신발<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001466">운동화</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000792">부츠</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000791">워커</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000784">모카신/털신</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000788">스니커즈</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000787">구두</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000666">실내화</a></li>
# </ul>
# </div>
# <div class="co_cel">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000186">시계<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001487">패션시계</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000426">아동시계</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000425">커플시계</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001488">시계소품</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000435">시계수리용품</a></li>
# </ul>
# </div>
# </div>
# <div class="co_col" style="height:442px">
# <div class="co_cel" style="height:189px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000176">여성가방<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000644">백팩</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000641">크로스백</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000639">숄더백</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000640">토트백</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000643">파우치</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000642">클러치백</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000645">힙색</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001468">가방소품</a></li>
# </ul>
# </div>
# <div class="co_cel">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000189">주얼리<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001489">반지</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001490">귀걸이</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001491">목걸이</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001492">펜던트</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001495">팔찌</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50006174">발찌</a></li>
# </ul>
# </div>
# </div>
# <div class="co_col" style="height:442px">
# <div class="co_cel" style="height:189px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000177">남성가방<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000651">백팩</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000648">크로스백</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000646">숄더백</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000647">토트백</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000650">브리프케이스</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000649">클러치백</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000652">힙색</a></li>
# </ul>
# </div>
# <div class="co_cel">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000181">모자<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001475">스냅백</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50006868">베레모</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001474">야구모자</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000541">군모</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000543">비니</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000548">귀달이모자</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000549">방울털모자</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000550">귀마개</a></li>
# </ul>
# </div>
# </div>
# <div class="co_col" style="height:442px">
# <div class="co_cel" style="height:189px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000178">여행용 가방/소품<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001469">하드캐리어</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001470">소프트캐리어</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000653">보스턴가방</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000658">여행소품케이스</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000183">선글라스/안경테</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50005464">캐리어소품</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50006908">캐리어커버</a></li>
# </ul>
# </div>
# <div class="co_cel">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000185">기타잡화<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000185">패션소품</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001479">스카프</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000565">머플러</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001481">넥타이</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000566">넥워머</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000182">장갑</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000180">벨트</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000166">양말</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="co_help">
# <a class="co_all" href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000001">패션잡화 카테고리 전체보기<span class="co_more"></span></a><!--N=a:SNB*l.more-->
# <a class="co_close" href="https://search.shopping.naver.com/category/category.nhn?cat_id="><span class="blind">패션잡화 카테고리 닫기</span></a><!--N=a:SNB*l.close-->
# </div>
# </div>
# </li>
# <li class="co_menu_beauty">
# <a class="_category1" href="javascript:;"><em>화장품/미용</em></a><!--N=a:SNB*l.50000002-->
# <div class="co_ly_inner">
# <div class="co_position">
# <div class="co_col" style="height:442px">
# <div class="co_cel" style="height:169px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000190">스킨케어<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000437">스킨/토너</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000438">로션</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000439">에센스</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000440">크림</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000441">아이케어</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000342">넥케어</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000442">미스트</a></li>
# </ul>
# </div>
# <div class="co_cel" style="height:169px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000193">마스크/팩<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000463">마스크시트</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000464">필오프팩</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000465">워시오프팩</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000466">코팩</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000467">수면팩</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000468">마사지크림/젤</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000469">마스크/팩세트</a></li>
# </ul>
# </div>
# <div class="co_cel">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000202">남성화장품<span class="co_more">전체보기</span></a></strong>
# </div>
# </div>
# <div class="co_col" style="height:442px">
# <div class="co_cel" style="height:169px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000191">선케어<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000445">선크림</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000446">선스프레이</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000447">선스틱</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000448">선파우더/쿠션</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001496">태닝</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000449">애프터선</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000450">선케어세트</a></li>
# </ul>
# </div>
# <div class="co_cel" style="height:169px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000198">헤어케어<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000297">샴푸</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000298">린스</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000299">트리트먼트</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000300">헤어에센스</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000301">헤어팩</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000302">헤어미스트</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000303">두피케어</a></li>
# </ul>
# </div>
# <div class="co_cel">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000200">향수<span class="co_more">전체보기</span></a></strong>
# </div>
# </div>
# <div class="co_col" style="height:442px">
# <div class="co_cel" style="height:169px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000194">베이스메이크업<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000470">BB크림</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000471">CC크림</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000472">프라이머</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000345">메이크업베이스</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001369">파우더</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000346">트윈케이크</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001370">파운데이션</a></li>
# </ul>
# </div>
# <div class="co_cel" style="height:169px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000199">헤어스타일링<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000306">헤어왁스</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000307">헤어스프레이</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000308">헤어무스</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000309">헤어젤</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000310">헤어글레이즈</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000311">염색약</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001372">파마약</a></li>
# </ul>
# </div>
# <div class="co_cel">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000201">뷰티소품<span class="co_more">전체보기</span></a></strong>
# </div>
# </div>
# <div class="co_col" style="height:442px">
# <div class="co_cel" style="height:169px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000195">색조메이크업<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000391">립스틱</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000392">립케어</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000393">립글로스</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000394">립틴트</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000395">립라이너</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000396">아이섀도</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001371">아이라이너</a></li>
# </ul>
# </div>
# <div class="co_cel" style="height:169px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000197">바디케어<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000408">바디로션</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000281">바디크림</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000282">바디오일</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000283">바디미스트</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000284">바디파우더</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000285">바디클렌저</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000293">데오드란트</a></li>
# </ul>
# </div>
# </div>
# <div class="co_col" style="height:442px">
# <div class="co_cel" style="height:169px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000192">클렌징<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000451">클렌징폼</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000452">클렌징오일</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000453">클렌징크림</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000454">클렌징로션</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000455">클렌징젤</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000456">클렌징워터</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000457">클렌징티슈</a></li>
# </ul>
# </div>
# <div class="co_cel">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000196">네일케어<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000402">매니큐어</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000403">네일아트</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000404">네일영양제</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000405">네일리무버</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000406">네일케어도구</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000407">네일케어세트</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="co_help">
# <a class="co_all" href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000002">화장품 / 미용 카테고리 전체보기<span class="co_more"></span></a><!--N=a:SNB*l.more-->
# <a class="co_close" href="https://search.shopping.naver.com/category/category.nhn?cat_id="><span class="blind">화장품 / 미용 카테고리 닫기</span></a><!--N=a:SNB*l.close-->
# </div>
# </div>
# </li>
# <li class="co_menu_digital">
# <a class="_category1" href="javascript:;" id="_digitalCategory1"><em>디지털/가전</em></a><!--N=a:SNB*l.50000003-->
# <div class="co_ly_inner">
# <div class="co_position">
# <div class="co_col" style="height:452px">
# <div class="co_cel">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000204">휴대폰<span class="co_more">전체보기</span></a></strong>
# </div>
# <div class="co_cel" style="height:106px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000205">휴대폰 액세서리<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001377">휴대폰 케이스</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001378">휴대폰 보호필름</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001380">휴대폰 배터리</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001379">휴대폰 충전기</a></li>
# </ul>
# </div>
# <div class="co_cel">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000212">계절가전<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001421">에어컨</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001420">선풍기</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001419">냉풍기</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001427">제습기</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001425">가습기</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001426">공기정화기</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001429">전기장판/담요/방석</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001428">전기매트</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001852">전기히터</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001422">온풍기</a></li>
# </ul>
# </div>
# </div>
# <div class="co_col" style="height:452px">
# <div class="co_cel">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000151">노트북<span class="co_more">전체보기</span></a></strong>
# </div>
# <div class="co_cel" style="height:106px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000206">카메라/캠코더 용품<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000265">DSLR 카메라</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000266">미러리스 디카</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000267">일반 디카</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001381">카메라 렌즈</a></li>
# </ul>
# </div>
# <div class="co_cel" style="height:106px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000210">생활가전<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001408">세탁기</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001410">청소기</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001411">다리미</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001412">디지털 도어록</a></li>
# </ul>
# </div>
# <div class="co_cel" style="height:106px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000213">주방가전<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001430">냉장고</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001305">가스레인지</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001306">전기밥솥</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001708">커피메이커</a></li>
# </ul>
# </div>
# </div>
# <div class="co_col" style="height:452px">
# <div class="co_cel">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000152">태블릿PC<span class="co_more">전체보기</span></a></strong>
# </div>
# <div class="co_cel" style="height:106px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000208">영상가전<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001395">TV</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001397">프로젝터</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001399">영상플레이어</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50002014">디지털 액자</a></li>
# </ul>
# </div>
# <div class="co_cel" style="height:106px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000209">음향가전<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001400">홈시어터</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001976">이어폰</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001977">헤드폰</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001406">블루투스셋</a></li>
# </ul>
# </div>
# <div class="co_cel" style="height:106px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000211">이미용가전<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001417">면도기</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001986">드라이어</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001988">매직기</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001995">피부케어기기</a></li>
# </ul>
# </div>
# </div>
# <div class="co_col" style="height:452px">
# <div class="co_cel">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000089">PC<span class="co_more">전체보기</span></a></strong>
# </div>
# <div class="co_cel" style="height:106px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000094">PC주변기기<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001203">마우스</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001204">키보드</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001206">복합기</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001207">프린터</a></li>
# </ul>
# </div>
# <div class="co_cel" style="height:106px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000096">저장장치<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001600">외장HDD</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001601">외장SSD</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001617">SSD</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001615">USB메모리</a></li>
# </ul>
# </div>
# <div class="co_cel" style="height:106px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000088">게임/타이틀<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001733">가정용 게임기</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001734">휴대용 게임기</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001736">게임 타이틀</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001735">PC 게임</a></li>
# </ul>
# </div>
# </div>
# <div class="co_col" style="height:452px">
# <div class="co_cel">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000153">모니터<span class="co_more">전체보기</span></a></strong>
# </div>
# <div class="co_cel" style="height:106px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000097">PC부품<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001620">CPU</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001218">RAM</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001219">그래픽카드</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001220">메인보드</a></li>
# </ul>
# </div>
# <div class="co_cel" style="height:106px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000098">네트워크 장비<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001226">공유기</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001227">랜카드</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001506">스위칭허브</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001504">블루투스동글</a></li>
# </ul>
# </div>
# <div class="co_cel" style="height:106px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000214">자동차기기<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001188">블랙박스/액세서리</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001189">내비게이션/액세서리</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001190">하이패스/GPS</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001191">전방/후방 카메라</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="co_help">
# <a class="co_all" href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000003">디지털 / 가전 카테고리 전체보기<span class="co_more"></span></a><!--N=a:SNB*l.more-->
# <a class="co_close" href="https://search.shopping.naver.com/category/category.nhn?cat_id="><span class="blind">디지털 / 가전 카테고리 닫기</span></a><!--N=a:SNB*l.close-->
# </div>
# </div>
# </li>
# <li class="co_menu_interior">
# <a class="_category1" href="javascript:;"><em>가구/인테리어</em></a><!--N=a:SNB*l.50000004-->
# <div class="co_ly_inner">
# <div class="co_position">
# <div class="co_col" style="height:400px">
# <div class="co_cel" style="height:148px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000100">침실가구<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001228">침대</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001229">매트리스</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001230">장롱/붙박이장</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001231">화장대</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001232">거울</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50007189">서랍장</a></li>
# </ul>
# </div>
# <div class="co_cel" style="height:148px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000101">거실가구<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001234">소파</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001235">테이블</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001310">TV거실장</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001311">장식장</a></li>
# </ul>
# </div>
# <div class="co_cel">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000104">아동/주니어가구<span class="co_more">전체보기</span></a></strong>
# </div>
# </div>
# <div class="co_col" style="height:400px">
# <div class="co_cel" style="height:148px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000102">주방가구<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001236">식탁/의자</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001313">레인지대</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001315">왜건/카트</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001316">주방수납장</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001317">그릇장/컵보드</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001318">기타주방가구</a></li>
# </ul>
# </div>
# <div class="co_cel" style="height:148px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000105">서재/사무용가구<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001238">책상</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001346">책장</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001347">책꽂이</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001239">의자</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001240">사무/교구용 가구</a></li>
# </ul>
# </div>
# <div class="co_cel">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000106">아웃도어가구<span class="co_more">전체보기</span></a></strong>
# </div>
# </div>
# <div class="co_col" style="height:400px">
# <div class="co_cel" style="height:148px">
# <strong><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50000103">수납가구<span class="co_more">전체보기</span></a></strong>
# <ul>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001319">행거</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001320">수납장</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001321">선반</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001322">공간박스</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001329">코너장</a></li>
# <li><a href="https://search.shopping.naver.com/category/category.nhn?cat_id=50001330">소품수납함</a></li>
# </ul>
# </div>
# <div class="co_cel" style="height:148px">
# ...
# <span class="npay">네이버페이 가맹점</span>
# <span class="power_txt">클렌징부터 보습 <strong>화장품</strong>까지 깨끗하게 담아낸, 순한 <strong>화장품</strong> 오르템!</span>
# </li>
# <li>
# <a class="power_tit" href="https://adcr.naver.com/adcr?x=JlrsbOXZa2YhGJIiPYoszf///w==..." target="_blank">GC녹십자<strong>화장품</strong> 분자</a><!--N=a:pwl.title,r:2-->
# <a class="power_address" href="https://adcr.naver.com/adcr?x=JlrsbOXZa2YhGJIiPYoszf///w==..." target="_blank">http://www.boonja.co.kr</a><!--N=a:pwl.url,r:2-->
# <span class="npay">네이버페이 가맹점</span>
# <span class="power_txt">참여인원 1천명, 1여 년간의 테스트, 100번이 넘는 샘플링으로 탄생한 <strong>화장품</strong></span>
# </li>
# <li>
# <a class="power_tit" href="https://adcr.naver.com/adcr?x=rEe8CUls0JOTYjAr7NkBmf///w==..." target="_blank">RAYBLELON(레이블론)</a><!--N=a:pwl.title,r:3-->
# <a class="power_address" href="https://adcr.naver.com/adcr?x=rEe8CUls0JOTYjAr7NkBmf///w==..." target="_blank">http://www.rayblelon.com</a><!--N=a:pwl.url,r:3-->
# <span class="nlogin _nlogin">N 네이버 아이디로 로그인</span>
# <span class="power_txt">안전한 성분 유리가루걱정없이 피부샵에서 받아왔던 관리를 집에서 간편하게 즐기세요.</span>
# </li>
# <li>
# <a class="power_tit" href="https://adcr.naver.com/adcr?x=4Un5voUPpbhMg+rs0s8PUv///w==..." target="_blank">내 피부의 자신감, 어바웃미</a><!--N=a:pwl.title,r:4-->
# <a class="power_address" href="https://adcr.naver.com/adcr?x=4Un5voUPpbhMg+rs0s8PUv///w==..." target="_blank">https://www.aboutmeshop.com/</a><!--N=a:pwl.url,r:4-->
# <span class="nlogin _nlogin">N 네이버 아이디로 로그인</span>
# <span class="power_txt">건조함에 메말라버린 피부에 필요한 최적의 뷰티, 100년 역사의 기술! 어바웃미</span>
# </li>
# <li>
# <a class="power_tit" href="https://adcr.naver.com/adcr?x=wCEaTNwqweZQoEBHLw6e3////w==..." target="_blank">비타민크림 비교 소비자X파일</a><!--N=a:pwl.title,r:5-->
# <a class="power_address" href="https://adcr.naver.com/adcr?x=wCEaTNwqweZQoEBHLw6e3////w==..." target="_blank">https://blog.naver.com/thelemon87</a><!--N=a:pwl.url,r:5-->
# <span class="power_txt">소비자X파일 성분분석, 피부과전문의 논문 임상결과 자료, 비타민크림 제품 품질비교</span>
# </li>
# </ul>
# <a class="btn_choice" href="https://saedu.naver.com/adbiz/searchad/intro.nhn" target="_blank">등록 안내<span>바로가기</span></a><!--N=a:pwl.help-->
# </div>
# <!-- //power_link -->
# </div>
# </div>
# <!-- 담기 레이어 -->
# <div class="ly_share _ly_share" style="display:none;top:813px;left:70px">
# <span class="arrow_top"></span>
# <ul>
# <li><a class="_share_to_blog" href="#">내 블로그에 담기</a></li>
# <li><a class="_share_to_cafe" href="#">카페에 담기</a></li>
# </ul>
# <div class="naver-splugin" style="display: none;"></div>
# </div>
# <!-- //담기 레이어 -->
# <!-- 모바일 QR코드 -->
# <div class="ly_code _ly_code" style="display:none;left:369px;top:1253px">
# <p class="ly_tit"><strong>모바일 QR코드</strong></p>
# <p class="code_txt">
# <strong>모바일에서 구매시<br/>더 저렴합니다.</strong>
# <em>우측의 QR코드 또는 하단의<br/><span class="tit">찜하기</span>를 통해 모바일에서<br/>최저가를 확인하세요</em>
# <a class="btn_jjim _qr_btn_jjim" href="#"><span></span>찜하기</a>
# </p>
# <div class="code_img"><img alt="m.naver.com 바로가기 QR코드" class="_qr_img" height="130" src="" width="130"/></div>
# <a class="btn_pop_close _qr_close" href="#">모바일 QR코드 닫기</a>
# </div>
# <!-- //모바일 QR코드 -->
# <!-- 몰정보 레이어 -->
# <div class="ly_mall _ly_mall" id="_ly_mall" style="display:none;left:360px;top:1683px">
# <p class="ly_mall_tit">쇼핑몰 정보</p>
# <div class="mall_guide">
# <div class="mall_img _ly_mall_img_url"><img alt="" src=""/><span class="mask"></span></div>
# <div class="text_area">
# <strong class="tit _ly_mall_name"></strong>
# <span class="txt _ly_mall_introduction"></span>
# <div class="etc">
# <span class="piece">상품수<span class="num _ly_mall_product_count"></span></span>
# <a class="view_detail _ly_mall_more" href="#" target="_blank">전체상품보기<span></span></a>
# </div>
# </div>
# </div>
# <div class="mall_tbl_area v2">
# <table border="1" class="mall_tbl">
# <caption>쇼핑몰 정보</caption>
# <colgroup><col style="width:115px"/><col/></colgroup>
# <tbody>
# <tr>
# <th scope="row">주소</th>
# <td class="txt_over _ly_mall_address"></td>
# </tr>
# <tr>
# <th scope="row">사업자등록번호</th>
# <td class="_ly_mall_cno"></td>
# </tr>
# <tr>
# <th scope="row">통신판매업신고</th>
# <td class="_ly_mall_reg_no"></td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="mall_grade">
# <strong class="tit">몰 등급 안내</strong>
# <span class="txt">쇼핑몰의 성격에 따라 아래 기준으로 몰 등급이 부여됩니다.</span>
# <div class="etc">
# <span class="piece">스마트스토어 : 판매건수, 판매금액 기준</span>
# <span class="piece">쇼핑광고주: 판매실적에 따른 수수료 및 거래액 기준</span>
# </div>
# </div>
# <a class="btn_pop_close _btn_pop_close_mall" href="#">몰정보 레이어 닫기</a>
# </div>
# <!-- //몰정보 레이어 -->
# <!-- 구매정보 상세 레이어 -->
# <div class="ly_mall _ly_shopping" id="ly_benefit" style="display:none;left:360px;top:1483px"><!-- [D] 활성화시 style="display:block" -->
# <p class="ly_mall_tit">구매정보</p>
# <div class="mall_tbl_area v2">
# <table border="1" class="mall_tbl">
# <caption>구매정보</caption>
# <colgroup><col style="width:135px"/><col/></colgroup>
# <tbody>
# <tr class="_naverpay_row" style="display: none">
# <th scope="row">포인트</th>
# <td class="_ly_naverpay">네이버페이 포인트 <em>1%</em></td>
# </tr>
# <tr class="_coupon_row" style="display: none">
# <th scope="row">할인</th>
# <td class="_ly_coupon">
# <p class="benefits"><span>첫구매 상품중복할인 280원</span></p>
# </td>
# </tr>
# <tr class="_promotion_row" style="display: none">
# <th scope="row">추가할인</th>
# <td class="txt_over _ly_promotion">네이버쇼핑 <em>5%</em> 추가할인</td>
# </tr>
# <tr class="_delivery_row" style="display: none">
# <th scope="row">배송</th>
# <td class="txt_over _ly_delivery">
#                     2,500원 <span class="delivery_today">오늘출발<em class="delivery_limited">(평일 4시 주문마감)</em></span>
# <span class="delivery_method">택배 CJ대한통운, 퀵배송 방문수령</span>
# </td>
# </tr>
# <tr class="_delivery_fee_row" style="display: none">
# <th scope="row">배송비 옵션</th>
# <td class="txt_over _ly_delivery_fee">
#                     제주/도서산간을 제외한 지역별 차등 배송비 발생
#                 </td>
# </tr>
# <tr class="_return_fee_row" style="display: none">
# <th scope="row">반품배송비</th>
# <td class="txt_over _ly_return_fee">
#                     5,000원
#                 </td>
# </tr>
# <tr class="_card_discount_row" style="display: none">
# <th scope="row">할인</th>
# <td class="txt_over _ly_card_discount">
#                     롯데카드 6,160원
#                 </td>
# </tr>
# <tr class="_no_interest_row" style="display: none">
# <th scope="row">무이자할부</th>
# <td class="txt_over _ly_no_interest">
#                     IBK기업은행 12개월
#                 </td>
# </tr>
# </tbody>
# </table>
# <p class="caution">상품 가격은 쿠폰이 적용된 가격이며, 쇼핑몰 결제 페이지에서 쿠폰을 적용해야 해당 가격으로 구매 가능합니다.</p>
# </div>
# <a class="btn_pop_close _btn_pop_close_shopping" href="#">상세정보 레이어 닫기</a><!--N=a:tpc.infox-->
# </div>
# <!-- 해외직구 몰정보 레이어 -->
# <div class="ly_mall _ly_overseas_mall" id="_ly_overseas_mall" style="display:none;left:360px;top:1683px"><!-- [D] 활성화시 style="display:block" 위치는 left, top으로 조절 -->
# <p class="ly_mall_tit">몰 상세정보</p>
# <p class="mall_txt"><span class="mall_img _ly_overseas_mall_link_url"><img alt="" class="_ly_overseas_mall_img_url" src=""/></span></p>
# <a class="mall_more _ly_overseas_mall_more" href="#">상품만 보기<span></span></a>
# <div class="mall_tbl_area">
# <table border="1" class="mall_tbl">
# <caption>몰 상세정보</caption>
# <colgroup><col style="width:115px"/><col/></colgroup>
# <tbody>
# <tr>
# <td class="txt_overseas" colspan="2"><div class="min_txt _ly_overseas_mall_address"></div></td>
# </tr>
# </tbody>
# </table>
# </div>
# <a class="btn_pop_close _btn_pop_close_overseas_mall" href="#">몰 상세정보 레이어 닫기</a>
# </div>
# <!-- //해외직구 몰정보 레이어 -->
# <div class="lpop_wrap" id="_price_reload" style="display:none;left:0;top:0px">
# <div class="lpop_cont">
# <p class="lpop_normalc">가격 갱신일 <span class="num"></span></p>
# </div>
# <span class="arr"></span>
# </div>
# <div class="lpop_wrap2" id="_exchange_rate_layer" style="display:none;left:200px;top:330px">
# <div class="lpop_cont">
# <p class="lpop_normalc3"></p>
# </div>
# <span class="arr"></span>
# </div>
# <div class="lpop_wrap2" id="_productAdNpayLayer" style="display:none;left:886px;top:880px;width:175px">
# <div class="lpop_cont">
# <p class="lnpay_go">네이버페이 포인트 파워적립 상품<a href="https://help.pay.naver.com/faq/content.nhn?faqId=3150" target="_blank"><em>NAVER pay</em> 파워적립 안내</a></p>
# </div>
# <span class="arr"></span>
# </div>
# </div>
# <a class="wrap_top" href="#u_skip">맨위로가기</a>
# <div class="g_footer" id="footer">
# <div class="co_footer">
# <h2 class="blind">하위영역</h2>
# <div class="co_info_site">
# <a href="https://www.naver.com/rules/service.html" target="_blank">네이버 이용약관</a><!-- N=a:fot.agreement -->
# <span class="co_bar">|</span>
# <a href="http://pay.naver.com/provision?viewType=use" target="_blank">네이버페이 이용약관</a><!-- N=a:fot.payagreement -->
# <span class="co_bar">|</span>
# <a href="https://www.naver.com/rules/privacy.html" target="_blank"><strong>개인정보처리방침</strong></a><!-- N=a:fot.privacy -->
# <span class="co_bar">|</span>
# <a href="https://shopping.naver.com/user/legalbasis.nhn" target="_blank">법적고지 및 주의사항</a><!-- N=a:fot.disclaimer -->
# <span class="co_bar">|</span>
# <a href="https://join.shopping.naver.com/index.nhn" target="_blank">입점안내</a><!-- N=a:fot.join -->
# <span class="co_bar">|</span>
# <a href="https://sell.storefarm.naver.com/#/home/about?tipModal=WINDOW_EXPOSURE&amp;tap=style" target="_blank">쇼핑윈도 노출안내</a><!-- N=a:fot.shoppingw -->
# <span class="co_bar">|</span>
# <a href="https://adcenter.shopping.naver.com" target="_blank">쇼핑파트너센터</a><!-- N=a:fot.ad -->
# <span class="co_bar">|</span>
# <a href="https://sell.storefarm.naver.com/#/home/about" target="_blank">스마트스토어센터</a><!-- N=a:fot.sfsell -->
# <span class="co_bar">|</span>
# <a href="https://help.pay.naver.com/index.nhn" target="_blank">쇼핑&amp;페이 고객센터</a><!-- N=a:fot.help -->
# </div>
# <p class="co_marketing">네이버㈜는 통신판매중개자이며, 통신판매의 당사자가 아닙니다. 상품, 상품정보, 거래에 관한 의무와 책임은 판매자에게 있습니다.</p>
# <address class="co_address">
# <span class="co_item">사업자등록번호 : 220-81-62517</span>
# <span class="co_item">통신판매업신고번호 : 제2006-경기성남-692호</span>
# <span class="co_item">대표이사 : 한성숙</span>
# <a class="item" href="http://www.ftc.go.kr/bizCommPop.do?wrkr_no=2208162517" target="_blank">
# 				사업자등록정보확인
# 			</a>
# <br>
# <span class="co_item">주소 : 경기도 성남시 분당구 불정로 6 네이버 그린팩토리 13561</span>
# <span class="co_item">대표전화 : 1588-3819</span>
# <span class="co_item"><a href="https://help.pay.naver.com/faq/alias/naver-gu.help" target="_blank"><strong>1:1문의 바로가기</strong></a></span>
# <span class="co_item">호스팅 서비스 제공 : NAVER Business Platform</span>
# </br></address>
# <p class="co_copyright"><a class="co_logo" href="https://www.naver.com" target="_blank">NAVER</a><!-- N=a:fot.naver -->Copyright © <strong><a href="https://www.navercorp.com" target="_blank">NAVER Corp.</a><!-- N=a:fot.navercorp --></strong> All Rights Reserved.</p>
# </div>
# </div>
# <div class="lpop_wrap2" id="_npayCommonLayer" style="display:none;left:180px;top:300px;width:170px">
# <div class="lpop_cont"></div>
# <span class="arr"></span>
# </div>
# <div class="lpop_wrap2" id="_scioCommonLayer" style="display:none;left:180px;top:300px;width:138px">
# <div class="lpop_cont"></div>
# <span class="arr"></span>
# </div>
# <div class="lpop_wrap2" id="_nLoginCommonLayer" style="display:none;left:180px;top:260px;width:195px">
# <div class="lpop_cont">
# <p class="lnpay_go">네이버 아이디로 로그인이 가능합니다.<br/><a href="https://nid.naver.com/user2/campaign/introNaverIdLogin.nhn" target="_blank">서비스 자세히 보기</a></p>
# </div>
# <span class="arr"></span>
# </div>
# </div>
# <script charset="utf-8" src="https://ssl.pstatic.net/imgshopping/static/pc-real-2019/js/_lib_v1.js?202003031700" type="text/javascript"></script><script src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn?2020030621" type="text/javascript"></script>
# <script charset="utf-8" src="https://ssl.pstatic.net/imgshopping/static/pc-real-2019/js/_autocomplete_v1.js?202003031700" type="text/javascript"></script><script charset="utf-8" src="https://ssl.pstatic.net/imgshopping/static/pc-real-2019/js/_layout_default_v1.js?202003031700" type="text/javascript"></script><script type="application/javascript">
# var __PHASE__ = "REAL";
# </script>
# <script charset="utf-8" src="https://ssl.pstatic.net/imgshopping/static/pc-real-2019/js/_search_v1.js?202003031700" type="text/javascript"></script><!--[if lt IE 9]>
# <script src="/js/respond/respond.src.js"></script>
# <link href="https://ssl.pstatic.net/imgshopping/static/pc2014/js/respond/respond-proxy.html" id="respond-proxy" rel="respond-proxy" />
# <link href="/js/respond/respond.proxy.gif" id="respond-redirect" rel="respond-redirect" />
# <script src="/js/respond/respond.proxy.js"></script>
# <![endif]-->
# <script type="text/javascript">
# 	g_ssc="svc.shopping.v3";g_pid="UE48Awpp7yCssAS+GCC-148909";g_query=shop.common.Base64.decode("7ZmU7J6l7ZKI");nclk_evt=1;nsc="svc.shopping.v3";
# 	// shop.exposeLogger.init();
# 	focusToSearch = true;
#
# 	// IE에서 ajax를 캐싱하는 오류 수정
# 	jQuery.ajaxSetup({
# 		cache: false
# 	});
#
# 	window.__LOAD_EVENT_NAME__ = 'onpageshow' in window ? 'pageshow' : 'load';
# 	jQuery(window).on(__LOAD_EVENT_NAME__, function (event) {
# 		if (__LOAD_EVENT_NAME__ == 'load' || !event.originalEvent.persisted) {
# 			g_pid ? lcs_do({"pid": g_pid}) : lcs_do();
# 			nclk_do();
# 			shop.exposeLogger.pv(document.location);
#
# 			shop.common.viewedProduct.init(); // 최근본상품 init
# 			shop.common.layer.init(); // 공통 레이어 init
# 		}
# 	});
#
#
# var aExact=[];var aInclude=[];var aExclude=[];jQuery(window).on(__LOAD_EVENT_NAME__,function(event){if(__LOAD_EVENT_NAME__=='load'||!event.originalEvent.persisted){shop.layout.detailSearch.init(shop.common.Base64.decode('7ZmU7J6l7ZKI'),aExact,aInclude,aExclude);shop.layout.defaultGnb.init();gnb_service="shopping";gnb_template="gnb_utf8";gnb_logout=encodeURIComponent(location.href);gnb_brightness=4;getGNB();jQuery('body').on('click',function(event){var parent=jQuery(event.target).parents('#gnb');if(parent.length==0){gnbAllLayerClose();}});}});jQuery(window).on(__LOAD_EVENT_NAME__,function(event){if(__LOAD_EVENT_NAME__=='load'||!event.originalEvent.persisted){shop.layout.defaultLnb.init();}});var oLoader;shop.exposeLogger.setCmpId(50000002)
# shop.exposeLogger.setCategoryIds([50000002,50000194,50001370,50005288])
# jQuery(document).ready(function(){var searchOptions={};searchOptions.origQuery=shop.common.Base64.decode('7ZmU7J6l7ZKI');searchOptions.brand=shop.common.Base64.decode('');searchOptions.maker=shop.common.Base64.decode('');searchOptions.spec=shop.common.Base64.decode('');searchOptions.series=shop.common.Base64.decode('');searchOptions.style=shop.common.Base64.decode('');searchOptions.mall=shop.common.Base64.decode('');searchOptions.color=shop.common.Base64.decode('');searchOptions.delivery=shop.common.Base64.decode('');searchOptions.pagingIndex=1;searchOptions.pagingSize=40;searchOptions.productSet='total';searchOptions.viewType='list';searchOptions.sort='rel';searchOptions.searchBy='';searchOptions.cat_id='';searchOptions.minPrice='';searchOptions.maxPrice='';searchOptions.free_deli=false;searchOptions.card_discount=false;searchOptions.coupon=false;searchOptions.point=false;searchOptions.promotion=false;searchOptions.agency=false;searchOptions.exagency=false;searchOptions.used=false;searchOptions.exused=false;searchOptions.oldModel=false;searchOptions.newModel=false;searchOptions.surl=shop.common.Base64.decode('');searchOptions.frm=shop.common.Base64.decode('');searchOptions.vertical=shop.common.Base64.decode('');var queryInfo={};queryInfo.eqq=new shop.common.HashMap();queryInfo.inq=new shop.common.HashMap();queryInfo.exq=new shop.common.HashMap();queryInfo.bq=shop.common.Base64.decode('7ZmU7J6l7ZKI');shop.search.loader.init(searchOptions,true,0,998999990,queryInfo,'F_SAS');shop.search.layerHandler.init();});jQuery(window).on(__LOAD_EVENT_NAME__,function(event){if(__LOAD_EVENT_NAME__=='load'||!event.originalEvent.persisted){shop.search.bannerHandler.init();}});jQuery(window).on(__LOAD_EVENT_NAME__,function(event){if(__LOAD_EVENT_NAME__=='load'||!event.originalEvent.persisted){var cat_id='50000002';var query=shop.common.Base64.decode('7ZmU7J6l7ZKI');shop.search.luckyTodayHandler.init(query);shop.search.themeShoppingHandler.init(query);shop.search.searchKeywordHandler.init(query);shop.pagelet.popularKeywordHandler.init();shop.search.popularBrandHandler.init(cat_id);shop.search.popularShoppingMallHandler.init(cat_id);shop.search.asideHandler.init();}});
# </script></body>
# </html>

# %%
item = bs_data.find("li", attrs={'class': '_model_list'})
price_span = item.find("span", attrs={'class': 'price'})
min_price = price_span.find("span",
                            attrs={
                                'class': ['num', 'price_reload']
                            }).text
print(min_price)
 
image_url = bs_data.find("img", attrs={'class': '_productLazyImg'})["src"] .split("?")[0]
print(image_url)
# Out:
# 12,200
# https://ssl.pstatic.net/imgshopping/static/pc2014/img/search/p_120_v1.png
